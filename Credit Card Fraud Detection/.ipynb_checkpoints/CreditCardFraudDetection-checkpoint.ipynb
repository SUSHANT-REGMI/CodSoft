# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Data Preprocessing

# %%
train_df = pd.read_csv(r'C:\Users\susha\Downloads\archive (8)\FraudDetection\fraudTrain.csv', index_col="Unnamed: 0")
test_df = pd.read_csv(r'C:\Users\susha\Downloads\archive (8)\FraudDetection\fraudTest.csv',  index_col="Unnamed: 0")

# %%
test_df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
train_df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
train_df.describe()
# Out:
#              cc_num           amt           zip           lat          long  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   4.171565e+17  7.027910e+01  4.880159e+04  3.853336e+01 -9.022626e+01
# std    1.308811e+18  1.599518e+02  2.689804e+04  5.076852e+00  1.375858e+01
# min    6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01 -1.656723e+02
# 25%    1.800400e+14  9.640000e+00  2.623700e+04  3.462050e+01 -9.679800e+01
# 50%    3.520550e+15  4.745000e+01  4.817400e+04  3.935430e+01 -8.747690e+01
# 75%    4.642260e+15  8.305000e+01  7.204200e+04  4.194040e+01 -8.015800e+01
# max    4.992350e+18  2.894890e+04  9.978300e+04  6.669330e+01 -6.795030e+01
#
#            city_pop     unix_time     merch_lat    merch_long      is_fraud
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   8.905776e+04  1.344906e+09  3.853346e+01 -9.022648e+01  5.727773e-03
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048575 entries, 0 to 1048574
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1048575 non-null  object
#  1   cc_num                 1048575 non-null  float64
#  2   merchant               1048575 non-null  object
#  3   category               1048575 non-null  object
#  4   amt                    1048575 non-null  float64
#  5   first                  1048575 non-null  object
#  6   last                   1048575 non-null  object
#  7   gender                 1048575 non-null  object
#  8   street                 1048575 non-null  object
#  9   city                   1048575 non-null  object
#  10  state                  1048575 non-null  object
#  11  zip                    1048575 non-null  int64
#  12  lat                    1048575 non-null  float64
#  13  long                   1048575 non-null  float64
# ...

# %%
fraud_count = train_df['is_fraud'].value_counts()
fraud_count
# Out:
# 0    1042569
# 1       6006
# Name: is_fraud, dtype: int64

# %%
fraud_count = test_df['is_fraud'].value_counts()
fraud_count
# Out:
# 0    553574
# 1      2145
# Name: is_fraud, dtype: int64

# %%
print(train_df.isna().sum().sum())
# Out:
# 0

# %%
print(train_df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #### There are way too many unnecessary attributes in the dataset, so we'll remove all of them at first before visualizing

# %%
train_df.drop(columns=['cc_num','first', 'last','zip', 'dob', 'trans_num','merch_lat', 'merch_long', 'lat', 'long'],inplace=True)
test_df.drop(columns=['cc_num','first', 'last','zip', 'dob', 'trans_num','merch_lat', 'merch_long', 'lat', 'long'],inplace=True)

# %%
train_df
# Out:
#         trans_date_trans_time                            merchant  \
# 0               1/1/2019 0:00          fraud_Rippin, Kub and Mann
# 1               1/1/2019 0:00     fraud_Heller, Gutmann and Zieme
# 2               1/1/2019 0:00                fraud_Lind-Buckridge
# 3               1/1/2019 0:01  fraud_Kutch, Hermiston and Farrell
# 4               1/1/2019 0:03                 fraud_Keeling-Crist
# ...                       ...                                 ...
# 1048570       3/10/2020 16:07                     fraud_Fadel Inc
# 1048571       3/10/2020 16:07    fraud_Cremin, Hamill and Reichel
# 1048572       3/10/2020 16:08  fraud_O'Connell, Botsford and Hand
# 1048573       3/10/2020 16:08              fraud_Thompson-Gleason
# 1048574       3/10/2020 16:08                 fraud_Buckridge PLC
#
#                category     amt gender                            street  \
# 0              misc_net    4.97      F                    561 Perry Cove
# ...

# %%
test_df
# Out:
#        trans_date_trans_time                              merchant  \
# 0        2020-06-21 12:14:25                 fraud_Kirlin and Sons
# 1        2020-06-21 12:14:33                  fraud_Sporer-Keebler
# 2        2020-06-21 12:14:53  fraud_Swaniawski, Nitzsche and Welch
# 3        2020-06-21 12:15:15                     fraud_Haley Group
# 4        2020-06-21 12:15:17                 fraud_Johnston-Casper
# ...                      ...                                   ...
# 555714   2020-12-31 23:59:07                 fraud_Reilly and Sons
# 555715   2020-12-31 23:59:09                  fraud_Hoppe-Parisian
# 555716   2020-12-31 23:59:15                       fraud_Rau-Robel
# 555717   2020-12-31 23:59:24                 fraud_Breitenberg LLC
# 555718   2020-12-31 23:59:34                     fraud_Dare-Marvin
#
#               category     amt gender                       street  \
# 0        personal_care    2.86      M            351 Darlene Green
# ...

# %%
train_df['street'].value_counts()
# Out:
# 4664 Sanchez Common Suite 930      2566
# 854 Walker Dale Suite 488          2559
# 29606 Martinez Views Suite 653     2542
# 2870 Bean Terrace Apt. 756         2532
# 8030 Beck Motorway                 2531
#                                    ...
# 3437 Ross Flat Apt. 592               7
# 27954 Hall Mill Suite 575             7
# 7065 Whitney Mountains                7
# 9599 Washington Field Suite 238       7
# 5273 Joseph Isle Suite 518            7
# Name: street, Length: 965, dtype: int64

# %%
len(train_df['street'].value_counts())
# Out:
# 965

# %%
encoder = LabelEncoder()
train_df["merchant"] = encoder.fit_transform(train_df["merchant"])
train_df["category"] = encoder.fit_transform(train_df["category"])
train_df["gender"] = encoder.fit_transform(train_df["gender"])
train_df["job"] = encoder.fit_transform(train_df["job"])

# %%
train_df
# Out:
#         trans_date_trans_time  merchant  category     amt  gender  \
# 0               1/1/2019 0:00       514         8    4.97       0
# 1               1/1/2019 0:00       241         4  107.23       0
# 2               1/1/2019 0:00       390         0  220.11       1
# 3               1/1/2019 0:01       360         2   45.00       1
# 4               1/1/2019 0:03       297         9   41.96       1
# ...                       ...       ...       ...     ...     ...
# 1048570       3/10/2020 16:07       166         5   77.00       0
# 1048571       3/10/2020 16:07       110         9  116.94       0
# 1048572       3/10/2020 16:08       456         6   21.27       0
# 1048573       3/10/2020 16:08       620         5    9.52       0
# 1048574       3/10/2020 16:08        83         9    6.81       0
#
#                                    street            city state  city_pop  \
# 0                          561 Perry Cove  Moravian Falls    NC      3495
# ...

# %%
fraud_count = train_df['is_fraud'].value_counts()
fraud_count
# Out:
# 0    1042569
# 1       6006
# Name: is_fraud, dtype: int64

# %%
fraudulence = ['not fraud', 'fruad']
fig = plt.figure(figsize=(10,5))
plt.bar(fraudulence, fraud_count, color = "#0cd3ef", width=0.4)
plt.ylabel("Count")
plt.title("no. of frauds")
plt.show()

# %% [markdown]
# ### From the bar graph, it is evident that the dataset is highly imbalanced

# %% [markdown]
# ### So, we'll look into methods to balance the dataset.
